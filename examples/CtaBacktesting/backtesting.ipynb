# %%
# %matplotlib inline

from vnpy.trader.app.ctaStrategy.ctaBacktesting import BacktestingEngine, OptimizationSetting, MINUTE_DB_NAME
from vnpy.trader.app.ctaStrategy.strategy.strategyAtrRsi import AtrRsiStrategy

# %%
# 创建回测引擎对象
engine = BacktestingEngine()

# %%
# 设置回测使用的数据
engine.setBacktestingMode(engine.BAR_MODE)    # 设置引擎的回测模式为K线
engine.setDatabase(MINUTE_DB_NAME, 'IF0000')  # 设置使用的历史数据库
engine.setStartDate('20120101')               # 设置回测用的数据起始日期

# %%
# 配置回测引擎参数
engine.setSlippage(0.2)     # 设置滑点为股指1跳
engine.setRate(0.3/10000)   # 设置手续费万0.3
engine.setSize(300)         # 设置股指合约大小 
engine.setPriceTick(0.2)    # 设置股指最小价格变动   
engine.setCapital(1000000)  # 设置回测本金

# %%
# 在引擎中创建策略对象
d = {'atrLength': 11}                     # 策略参数配置
engine.initStrategy(AtrRsiStrategy, d)    # 创建策略对象

# %%
# 运行回测
engine.runBacktesting()          # 运行回测
# Out:
# 2017-08-07 21:55:21.667000	开始载入数据
# 2017-08-07 21:55:21.877000	载入完成，数据量：331890
# 2017-08-07 21:55:21.877000	开始回测
# 2017-08-07 21:55:21.896000	策略初始化完成
# 2017-08-07 21:55:21.896000	策略启动完成
# 2017-08-07 21:55:21.896000	开始回放数据
# 2017-08-07 21:55:38.587000	数据回放结束

# %%
# 显示逐日回测结果
engine.showDailyResult()
# Out:
# 2017-08-07 21:55:42.845000	计算按日统计结果
# 2017-08-07 21:55:42.901000	------------------------------
# 2017-08-07 21:55:42.901000	首个交易日：	2012-01-11
# 2017-08-07 21:55:42.901000	最后交易日：	2017-03-20
# 2017-08-07 21:55:42.901000	总交易日：	1259
# 2017-08-07 21:55:42.901000	盈利交易日	615
# 2017-08-07 21:55:42.901000	亏损交易日：	643
# 2017-08-07 21:55:42.901000	起始资金：	1000000
# 2017-08-07 21:55:42.901000	结束资金：	1,642,369.01
# 2017-08-07 21:55:42.901000	总收益率：	64.24
# 2017-08-07 21:55:42.901000	总盈亏：	642,369.01
# 2017-08-07 21:55:42.901000	最大回撤: 	-193,389.3
# 2017-08-07 21:55:42.901000	总手续费：	215,570.99
# 2017-08-07 21:55:42.902000	总滑点：	447,780.0
# 2017-08-07 21:55:42.902000	总成交金额：	7,185,699,600.0
# 2017-08-07 21:55:42.902000	总成交笔数：	7,462.0
# 2017-08-07 21:55:42.902000	日均盈亏：	510.22
# 2017-08-07 21:55:42.902000	日均手续费：	171.22
# 2017-08-07 21:55:42.902000	日均滑点：	355.66
# 2017-08-07 21:55:42.902000	日均成交金额：	5,707,465.93
# 2017-08-07 21:55:42.902000	日均成交笔数：	5.93
# 2017-08-07 21:55:42.902000	日均收益率：	0.04%
# 2017-08-07 21:55:42.902000	收益标准差：	1.11%
# 2017-08-07 21:55:42.902000	Sharpe Ratio：	0.56

# %%
# 显示逐笔回测结果
engine.showBacktestingResult()
# Out:
# 2017-08-07 21:56:02.252000	计算回测结果
# 2017-08-07 21:56:02.401000	------------------------------
# 2017-08-07 21:56:02.401000	第一笔交易：	2012-01-11 10:18:00
# 2017-08-07 21:56:02.401000	最后一笔交易：	2017-03-20 15:00:00
# 2017-08-07 21:56:02.401000	总交易次数：	3,732.0
# 2017-08-07 21:56:02.401000	总盈亏：	642,278.25
# 2017-08-07 21:56:02.401000	最大回撤: 	-196,352.03
# 2017-08-07 21:56:02.401000	平均每笔盈利：	172.1
# 2017-08-07 21:56:02.401000	平均每笔滑点：	120.0
# 2017-08-07 21:56:02.401000	平均每笔佣金：	57.77
# 2017-08-07 21:56:02.401000	胜率		37.11%
# 2017-08-07 21:56:02.401000	盈利交易平均值	8,596.05
# 2017-08-07 21:56:02.401000	亏损交易平均值	-4,799.0
# 2017-08-07 21:56:02.401000	盈亏比：	1.79

# %%
# 显示前10条成交记录
for i in range(10):
    print engine.tradeDict[str(i+1)].__dict__
# Out:
# {'orderID': '1', 'direction': u'\u591a', 'gatewayName': '', 'tradeID': '1', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-11 09:18:00', 'volume': 1, 'stopOrderID': '', 'rawData': None, 'vtTradeID': '1', 'offset': u'\u5f00\u4ed3', 'vtOrderID': '1', 'dt': datetime.datetime(2012, 1, 11, 9, 18), 'price': 2464.4, 'vtSymbol': ''}
# {'orderID': '2', 'direction': u'\u7a7a', 'gatewayName': '', 'tradeID': '2', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-11 10:18:00', 'volume': 1, 'stopOrderID': 'CtaStopOrder.60', 'rawData': None, 'vtTradeID': '2', 'offset': u'\u5e73\u4ed3', 'vtOrderID': '2', 'dt': datetime.datetime(2012, 1, 11, 10, 18), 'price': 2448.8, 'vtSymbol': ''}
# {'orderID': '3', 'direction': u'\u7a7a', 'gatewayName': '', 'tradeID': '3', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-11 10:19:00', 'volume': 1, 'stopOrderID': '', 'rawData': None, 'vtTradeID': '3', 'offset': u'\u5f00\u4ed3', 'vtOrderID': '3', 'dt': datetime.datetime(2012, 1, 11, 10, 19), 'price': 2448.4, 'vtSymbol': ''}
# {'orderID': '4', 'direction': u'\u591a', 'gatewayName': '', 'tradeID': '4', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-11 14:21:00', 'volume': 1, 'stopOrderID': 'CtaStopOrder.212', 'rawData': None, 'vtTradeID': '4', 'offset': u'\u5e73\u4ed3', 'vtOrderID': '4', 'dt': datetime.datetime(2012, 1, 11, 14, 21), 'price': 2456.4, 'vtSymbol': ''}
# {'orderID': '5', 'direction': u'\u591a', 'gatewayName': '', 'tradeID': '5', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-11 14:22:00', 'volume': 1, 'stopOrderID': '', 'rawData': None, 'vtTradeID': '5', 'offset': u'\u5f00\u4ed3', 'vtOrderID': '5', 'dt': datetime.datetime(2012, 1, 11, 14, 22), 'price': 2455.6, 'vtSymbol': ''}
# {'orderID': '6', 'direction': u'\u7a7a', 'gatewayName': '', 'tradeID': '6', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-11 14:57:00', 'volume': 1, 'stopOrderID': 'CtaStopOrder.247', 'rawData': None, 'vtTradeID': '6', 'offset': u'\u5e73\u4ed3', 'vtOrderID': '6', 'dt': datetime.datetime(2012, 1, 11, 14, 57), 'price': 2444.0, 'vtSymbol': ''}
# {'orderID': '7', 'direction': u'\u7a7a', 'gatewayName': '', 'tradeID': '7', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-11 14:58:00', 'volume': 1, 'stopOrderID': '', 'rawData': None, 'vtTradeID': '7', 'offset': u'\u5f00\u4ed3', 'vtOrderID': '7', 'dt': datetime.datetime(2012, 1, 11, 14, 58), 'price': 2445.8, 'vtSymbol': ''}
# {'orderID': '8', 'direction': u'\u591a', 'gatewayName': '', 'tradeID': '8', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-12 09:51:00', 'volume': 1, 'stopOrderID': 'CtaStopOrder.300', 'rawData': None, 'vtTradeID': '8', 'offset': u'\u5e73\u4ed3', 'vtOrderID': '8', 'dt': datetime.datetime(2012, 1, 12, 9, 51), 'price': 2453.0, 'vtSymbol': ''}
# {'orderID': '9', 'direction': u'\u591a', 'gatewayName': '', 'tradeID': '9', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-12 09:52:00', 'volume': 1, 'stopOrderID': '', 'rawData': None, 'vtTradeID': '9', 'offset': u'\u5f00\u4ed3', 'vtOrderID': '9', 'dt': datetime.datetime(2012, 1, 12, 9, 52), 'price': 2452.0, 'vtSymbol': ''}
# {'orderID': '10', 'direction': u'\u7a7a', 'gatewayName': '', 'tradeID': '10', 'exchange': '', 'symbol': '', 'tradeTime': '2012-01-12 10:31:00', 'volume': 1, 'stopOrderID': 'CtaStopOrder.339', 'rawData': None, 'vtTradeID': '10', 'offset': u'\u5e73\u4ed3', 'vtOrderID': '10', 'dt': datetime.datetime(2012, 1, 12, 10, 31), 'price': 2455.2, 'vtSymbol': ''}

# %%
# 优化配置
setting = OptimizationSetting()                 # 新建一个优化任务设置对象
setting.setOptimizeTarget('capital')            # 设置优化排序的目标是策略净盈利
setting.addParameter('atrLength', 12, 20, 2)    # 增加第一个优化参数atrLength，起始12，结束20，步进2
setting.addParameter('atrMa', 20, 30, 5)        # 增加第二个优化参数atrMa，起始20，结束30，步进5
setting.addParameter('rsiLength', 5)            # 增加一个固定数值的参数

# 执行多进程优化
import time
engine.runParallelOptimization(AtrRsiStrategy, setting)
print u'耗时：%s' %(time.time()-start)
